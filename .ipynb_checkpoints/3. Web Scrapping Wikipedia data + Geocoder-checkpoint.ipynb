# %%
import numpy as np
import pandas as pd

# %%
#Scrapping data from wikipedia

import requests
from lxml import html

pageContent=requests.get(
     'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
)
tree = html.fromstring(pageContent.content)
torontoTable = tree.xpath('//*[@id="mw-content-text"]/div/table[1]/tbody//text()')

# %%
#continue preprocess wikipedia data with XPATH

counter = 0
torontoArray =[]
torontoItem =""

for data in torontoTable:
    if data.strip() != '' and data.strip() != 'Postal code' and data.strip() != 'Borough' and data.strip() != 'Neighborhood' :
        if counter%3 == 0:
            if data.strip()[0] != 'M':
                continue
            torontoArray.append(torontoItem)
            torontoItem=data.strip()
        elif data.strip() != 'Not assigned':
            torontoItem =   torontoItem.strip() + "|" + data.strip().replace(" /", ",")
        else :
            torontoItem =   torontoItem.strip()  + "|" + data.strip().replace(" /", ",")
            counter = counter +1
        counter = counter +1
       
    
len(torontoArray)
# Out:
# 180

# %%
#Adding Latitude and Longtitude

import geocoder
torontoList = []

for item in torontoArray:
    if 'Not assigned' in item :
        continue
    else : 
        if item != '' :
            ItemValue = str(item).split("|")
            stringAddress = ItemValue[0] +", Toronto, Ontario"
            coordinates = geocoder.arcgis(stringAddress).latlng
            ItemValue.append(coordinates[0])
            ItemValue.append(coordinates[1])
            torontoList.append(ItemValue) 
            
torontoList
# Out:
# [['M3A', 'North York', 'Parkwoods', 43.75293455500008, -79.33564142299997],
#  ['M4A',
#   'North York',
#   'Victoria Village',
#   43.72810248500008,
#   -79.31188987099995],
#  ['M5A',
#   'Downtown Toronto',
#   'Regent Park, Harbourfront',
#   43.65096410900003,
#   -79.35304116399999],
#  ['M6A',
#   'North York',
#   'Lawrence Manor, Lawrence Heights',
#   43.723265465000054,
#   -79.45121077799996],
#  ['M7A',
#   'Downtown Toronto',
#   "Queen's Park, Ontario Provincial Government",
#   43.66179000000005,
#   -79.38938999999993],
#  ['M9A',
#   'Etobicoke',
#   'Islington Avenue',
#   43.66748067300006,
#   -79.52895286499995],
#  ['M1B',
#   'Scarborough',
#   'Malvern, Rouge',
#   43.80862623100006,
#   -79.18991284599997],
#  ['M3B', 'North York', 'Don Mills', 43.74890000000005, -79.35721999999998],
#  ['M4B',
#   'East York',
#   'Parkview Hill, Woodbine Gardens',
#   43.70719267700008,
#   -79.31152927299996],
#  ['M5B',
#   'Downtown Toronto',
#   'Garden District, Ryerson',
#   43.65749059800004,
#   -79.37752923699998],
#  ['M6B', 'North York', 'Glencairn', 43.70727872700007, -79.44750009299997],
#  ['M9B',
#   'Etobicoke',
#   'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale',
#   43.65002250300006,
#   -79.55408903099999],
#  ['M1C',
#   'Scarborough',
#   'Rouge Hill, Port Union, Highland Creek',
#   43.78577865700004,
#   -79.15736763799998],
#  ['M3C', 'North York', 'Don Mills', 43.72214339800007, -79.35202341799999],
#  ['M4C',
#   'East York',
#   'Woodbine Heights',
#   43.68974004200004,
#   -79.30850701899999],
#  ['M5C',
#   'Downtown Toronto',
#   'St. James Town',
#   43.65173364700007,
#   -79.37555358799995],
#  ['M6C', 'York', 'Humewood-Cedarvale', 43.69172991700003, -79.43001279899994],
#  ['M9C',
#   'Etobicoke',
#   'Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood',
#   43.637813150000056,
#   -79.57648363299995],
#  ['M1E',
#   'Scarborough',
#   'Guildwood, Morningside, West Hill',
#   43.76580607300008,
#   -79.18528434099994],
#  ['M4E', 'East Toronto', 'The Beaches', 43.67814827600006, -79.29534930999995],
#  ['M5E',
#   'Downtown Toronto',
#   'Berczy Park',
#   43.645195888000046,
#   -79.37385548899994],
#  ['M6E', 'York', 'Caledonia-Fairbanks', 43.68911756600005, -79.45065043699998],
#  ['M1G', 'Scarborough', 'Woburn', 43.77154467100007, -79.21813521299998],
#  ['M4G', 'East York', 'Leaside', 43.70941386000004, -79.36309957799995],
#  ['M5G',
#   'Downtown Toronto',
#   'Central Bay Street',
#   43.65607218800005,
#   -79.38565318999997],
#  ['M6G',
#   'Downtown Toronto',
#   'Christie',
#   43.668602116000045,
#   -79.42038731299994],
#  ['M1H', 'Scarborough', 'Cedarbrae', 43.76879106300004, -79.23881306799996],
#  ['M2H',
#   'North York',
#   'Hillcrest Village',
#   43.802556149000054,
#   -79.35656576499997],
#  ['M3H',
#   'North York',
#   'Bathurst Manor, Wilson Heights, Downsview North',
#   43.75739449200006,
#   -79.44239439999996],
#  ['M4H',
#   'East York',
#   'Thorncliffe Park',
#   43.70207200300007,
#   -79.35161423599999],
#  ['M5H',
#   'Downtown Toronto',
#   'Richmond, Adelaide, King',
#   43.65054164500003,
#   -79.38411611599997],
#  ['M6H',
#   'West Toronto',
#   'Dufferin, Dovercourt Village',
#   43.66491031700008,
#   -79.43866366999998],
#  ['M1J',
#   'Scarborough',
#   'Scarborough Village',
#   43.74420268600005,
#   -79.22872456899995],
#  ['M2J',
#   'North York',
#   'Fairview, Henry Farm, Oriole',
#   43.78030600000005,
#   -79.34868699999998],
#  ['M3J',
#   'North York',
#   'Northwood Park, York University',
#   43.76487186000003,
#   -79.49249695199995],
#  ['M4J', 'East York', 'East Toronto', 43.687045770000054, -79.33388995799999],
#  ['M5J',
#   'Downtown Toronto',
#   'Harbourfront East, Union Station, Toronto Islands',
#   43.62375000000003,
#   -79.36919999999998],
#  ['M6J',
#   'West Toronto',
#   'Little Portugal, Trinity',
#   43.64863621500007,
#   -79.41775187699994],
#  ['M1K',
#   'Scarborough',
#   'Kennedy Park, Ionview, East Birchmount Park',
#   43.72688089800005,
#   -79.26569363099998],
#  ['M2K',
#   'North York',
#   'Bayview Village',
#   43.780606885000054,
#   -79.37692081799997],
#  ['M3K', 'North York', 'Downsview', 43.73910091500005, -79.46763070999998],
#  ['M4K',
#   'East Toronto',
#   'The Danforth West, Riverdale',
#   43.683423910000045,
#   -79.35456407799995],
#  ['M5K',
#   'Downtown Toronto',
#   'Toronto Dominion Centre, Design Exchange',
#   43.64692288500004,
#   -79.38162557699997],
#  ['M6K',
#   'West Toronto',
#   'Brockton, Parkdale Village, Exhibition Place',
#   43.639921634000075,
#   -79.43123988199994],
#  ['M1L',
#   'Scarborough',
#   'Golden Mile, Clairlea, Oakridge',
#   43.71334044300005,
#   -79.28494163099998],
#  ['M2L',
#   'North York',
#   'York Mills, Silver Hills',
#   43.74936000000008,
#   -79.38068999999996],
#  ['M3L', 'North York', 'Downsview', 43.72999160200004, -79.51202680199998],
#  ['M4L',
#   'East Toronto',
#   'India Bazaar, The Beaches West',
#   43.668290659000036,
#   -79.31557771299998],
#  ['M5L',
#   'Downtown Toronto',
#   'Commerce Court, Victoria Hotel',
#   43.648283294000066,
#   -79.37875017599998],
#  ['M6L',
#   'North York',
#   'North Park, Maple Leaf Park, Upwood Park',
#   43.71352959500007,
#   -79.48872437199998],
#  ['M9L', 'North York', 'Humber Summit', 43.75938139500005, -79.55717381699998],
#  ['M1M',
#   'Scarborough',
#   'Cliffside, Cliffcrest, Scarborough Village West',
#   43.72353760300007,
#   -79.22835287899994],
#  ['M2M',
#   'North York',
#   'Willowdale, Newtonbrook',
#   43.79180026600005,
#   -79.40642782199996],
#  ['M3M', 'North York', 'Downsview', 43.733220000000074, -79.49769999999995],
#  ['M4M',
#   'East Toronto',
#   'Studio District',
#   43.648000000000025,
#   -79.33925999999997],
#  ['M5M',
#   'North York',
#   'Bedford Park, Lawrence Manor East',
#   43.735446609000064,
#   -79.41794403499995],
#  ['M6M',
#   'York',
#   'Del Ray, Mount Dennis, Keelsdale and Silverthorn',
#   43.695074962000035,
#   -79.48717932199997],
#  ['M9M',
#   'North York',
#   'Humberlea, Emery',
#   43.733682102000046,
#   -79.54438077099996],
#  ['M1N',
#   'Scarborough',
#   'Birch Cliff, Cliffside West',
#   43.696447877000026,
#   -79.26564232899995],
#  ['M2N', 'North York', 'Willowdale', 43.769076780000034, -79.41369502399994],
#  ['M3N', 'North York', 'Downsview', 43.75581917400007, -79.51997275199994],
#  ['M4N',
#   'Central Toronto',
#   'Lawrence Park',
#   43.72945456600007,
#   -79.38641531799993],
#  ['M5N',
#   'Central Toronto',
#   'Roselawn',
#   43.710634140000025,
#   -79.41874774499996],
#  ['M6N',
#   'York',
#   'Runnymede, The Junction North',
#   43.67685581100005,
#   -79.47869052799996],
#  ['M9N', 'York', 'Weston', 43.70549635400005, -79.52037009099996],
#  ['M1P',
#   'Scarborough',
#   'Dorset Park, Wexford Heights, Scarborough Town Centre',
#   43.76131000000004,
#   -79.26993999999996],
#  ['M2P',
#   'North York',
#   'York Mills West',
#   43.750260000000026,
#   -79.39835499999998],
#  ['M4P',
#   'Central Toronto',
#   'Davisville North',
#   43.71317113200007,
#   -79.38887016199999],
#  ['M5P',
#   'Central Toronto',
#   'Forest Hill North & West',
#   43.69446000000005,
#   -79.41027999999994],
#  ['M6P',
#   'West Toronto',
#   'High Park, The Junction South',
#   43.65872000000007,
#   -79.46314999999998],
#  ['M9P', 'Etobicoke', 'Westmount', 43.69629612800003, -79.53312611699994],
#  ['M1R',
#   'Scarborough',
#   'Wexford, Maryvale',
#   43.75004250000006,
#   -79.30053749999996],
#  ['M2R', 'North York', 'Willowdale', 43.77991227600006, -79.44522868999996],
#  ['M4R',
#   'Central Toronto',
#   'North Toronto West',
#   43.714138802000036,
#   -79.40645595899997],
#  ['M5R',
#   'Central Toronto',
#   'The Annex, North Midtown, Yorkville',
#   43.67491074000003,
#   -79.40393998899998],
#  ['M6R',
#   'West Toronto',
#   'Parkdale, Roncesvalles',
#   43.647839601000044,
#   -79.44838789999994],
#  ['M7R',
#   'Mississauga',
#   'Canada Post Gateway Processing Centre',
#   43.648690000000045,
#   -79.38543999999996],
#  ['M9R',
#   'Etobicoke',
#   'Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens',
#   43.68688713700004,
#   -79.56550730099997],
#  ['M1S', 'Scarborough', 'Agincourt', 43.79392980200004, -79.26569360999997],
#  ['M4S',
#   'Central Toronto',
#   'Davisville',
#   43.70332655200008,
#   -79.38564862099997],
#  ['M5S',
#   'Downtown Toronto',
#   'University of Toronto, Harbord',
#   43.66328128200007,
#   -79.39808791199994],
#  ['M6S',
#   'West Toronto',
#   'Runnymede, Swansea',
#   43.64972539000007,
#   -79.48269151199997],
#  ['M1T',
#   'Scarborough',
#   "Clarks Corners, Tam O'Shanter, Sullivan",
#   43.78490240700006,
#   -79.30472546399994],
#  ['M4T',
#   'Central Toronto',
#   'Moore Park, Summerhill East',
#   43.690328124000075,
#   -79.38352175499995],
#  ['M5T',
#   'Downtown Toronto',
#   'Kensington Market, Chinatown, Grange Park',
#   43.65349712200003,
#   -79.39740961799998],
#  ['M1V',
#   'Scarborough',
#   "Milliken, Agincourt North, Steeles East, L'Amoreaux East",
#   43.81799836300007,
#   -79.28088739199995],
#  ['M4V',
#   'Central Toronto',
#   'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   43.686377906000075,
#   -79.40237221299998],
#  ['M5V',
#   'Downtown Toronto',
#   'CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport',
#   43.64053911600007,
#   -79.39743510499994],
#  ['M8V',
#   'Etobicoke',
#   'New Toronto, Mimico South, Humber Bay Shores',
#   43.61007458300003,
#   -79.49975147199996],
#  ['M9V',
#   'Etobicoke',
#   'South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens',
#   43.74405485200003,
#   -79.58120294599996],
#  ['M1W',
#   'Scarborough',
#   "Steeles West, L'Amoreaux West",
#   43.80053000000004,
#   -79.32182999999998],
#  ['M4W',
#   'Downtown Toronto',
#   'Rosedale',
#   43.681892762000075,
#   -79.37670588599997],
#  ['M5W',
#   'Downtown Toronto',
#   'Stn A PO Boxes',
#   43.648700000000076,
#   -79.38544999999993],
#  ['M8W',
#   'Etobicoke',
#   'Alderwood, Long Branch',
#   43.60089538500006,
#   -79.54038692299997],
#  ['M9W', 'Etobicoke', 'Northwest', 43.71161519300006, -79.58835079199997],
#  ['M1X', 'Scarborough', 'Upper Rouge', 43.83476822500006, -79.20410074399996],
#  ['M4X',
#   'Downtown Toronto',
#   'St. James Town, Cabbagetown',
#   43.667656097000076,
#   -79.36732626299994],
#  ['M5X',
#   'Downtown Toronto',
#   'First Canadian Place, Underground city',
#   43.64826890100005,
#   -79.38188376699998],
#  ['M8X',
#   'Etobicoke',
#   'The Kingsway, Montgomery Road , Old Mill North',
#   43.65333956200004,
#   -79.50976584199998],
#  ['M4Y',
#   'Downtown Toronto',
#   'Church and Wellesley',
#   43.66665858500005,
#   -79.38147173199997],
#  ['M7Y',
#   'East Toronto',
#   'Business reply mail Processing CentrE',
#   43.648700000000076,
#   -79.38544999999993],
#  ['M8Y',
#   'Etobicoke',
#   "Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East",
#   43.632798483000045,
#   -79.49301657299998],
#  ['M8Z',
#   'Etobicoke',
#   'Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West',
#   43.62549000000007,
#   -79.52599999999995]]

# %%
#Adding into Pandas Dataframe
df = pd.DataFrame(torontoList, columns =['Postal code', 'Borough','Neighborhood', 'Latitude' , 'Longitude'])

# %%
df.shape
# Out:
# (103, 5)

# %%
df.head(12)
# Out:
#    Postal code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
#
#                                          Neighborhood   Latitude  Longitude
# 0                                           Parkwoods  43.752935 -79.335641
# 1                                    Victoria Village  43.728102 -79.311890
# 2                           Regent Park, Harbourfront  43.650964 -79.353041
# 3                    Lawrence Manor, Lawrence Heights  43.723265 -79.451211
# 4         Queen's Park, Ontario Provincial Government  43.661790 -79.389390
# 5                                    Islington Avenue  43.667481 -79.528953
# 6                                      Malvern, Rouge  43.808626 -79.189913
# 7                                           Don Mills  43.748900 -79.357220
# 8                     Parkview Hill, Woodbine Gardens  43.707193 -79.311529
# 9                            Garden District, Ryerson  43.657491 -79.377529
# 10                                          Glencairn  43.707279 -79.447500
# 11  West Deane Park, Princess Gardens, Martin Grov...  43.650023 -79.554089

# %%
from geopy.geocoders import Nominatim
import folium

address = 'Toronto, Ontario'
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
DisplayMap_folium = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'],  df['Neighborhood']):
    label = f'neighborhood: {neighborhood}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='#000fff',
        fill=True,
        fill_color='#000fff',
        fill_opacity=0.5,
        parse_html=False).add_to(DisplayMap_folium)  
    
DisplayMap_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-98262579546f> in <module>
# ----> 1 toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
#       2                                    latitudes=toronto_data['Latitude'],
#       3                                    longitudes=toronto_data['Longitude']
#       4                                   )
#
# NameError: name 'toronto_data' is not defined

# %%
# top 10 common venues in each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
  

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood  \
# 0                                        Agincourt
# 1                           Alderwood, Long Branch
# 2  Bathurst Manor, Wilson Heights, Downsview North
# 3                                  Bayview Village
# 4                Bedford Park, Lawrence Manor East
#
#         1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0              Breakfast Spot          Skating Rink       Badminton Court
# 1                 Gas Station     Convenience Store        Sandwich Place
# 2                        Bank           Coffee Shop           Pizza Place
# 3  Construction & Landscaping                 Trail           Flower Shop
# 4          Italian Restaurant           Coffee Shop        Sandwich Place
#
#          4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                  Supermarket      Sushi Restaurant     Fish & Chips Shop
# 1                  Pizza Place                   Pub              Pharmacy
# 2               Ice Cream Shop        Sandwich Place           Gas Station
# 3  Eastern European Restaurant     Electronics Store  Ethiopian Restaurant
# 4                         Café          Liquor Store       Thai Restaurant
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0           Fish Market           Flower Shop                 Field
# 1                   Gym           Coffee Shop  Ethiopian Restaurant
# 2           Supermarket   Fried Chicken Joint            Restaurant
# 3    Falafel Restaurant                  Farm        Farmers Market
# 4           Sports Club                   Pub      Sushi Restaurant
#
#   10th Most Common Venue
# 0    Dumpling Restaurant
# 1             Donut Shop
# 2                  Diner
# 3   Fast Food Restaurant
# 4      Indian Restaurant

# %%
from sklearn.cluster import KMeans
toclusters = 3

to_clustering = to_indian.drop(["Neighborhoods"], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=toclusters, random_state=1)
kmeans.fit_transform(to_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:20]
